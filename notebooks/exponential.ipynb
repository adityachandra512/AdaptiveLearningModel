# %% [markdown]
# # --- Exploration Notebook (EDA) ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os

# Add src to path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.preprocessing.data_cleaner import save_processed_dataset
from src.project_utils.data_loader import load_raw_student_data

# %%
# Load raw dataset
# Note: 'student_behavior.csv' was not found, using project's load_raw_student_data()
df = load_raw_student_data()

print("Shape:", df.shape)
df.head()
# Out:
# Merged Dataset Size: 382
# Shape: (382, 53)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel_y freetime_y  goout_y  Dalc_y  Walc_y health_y absences_y G1_y G2_y  \
# 0        4          3        4       1       1        3          4    0   11
# 1        5          3        3       1       1        3          2    9   11
# 2        4          3        2       2       3        3          6   12   13
# 3        3          2        2       1       1        5          0   14   14
# ...

# %%
# --- Summary statistics ---
df.describe(include="all")
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     382  382  382.000000     382     382     382  382.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      342  198         NaN     301     278     344         NaN
# mean      NaN  NaN   16.586387     NaN     NaN     NaN    2.806283
# std       NaN  NaN    1.173470     NaN     NaN     NaN    1.086381
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   17.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...    famrel_y  freetime_y     goout_y  \
# count   382.000000    382    382  ...  382.000000  382.000000  382.000000
# ...

# %%
# --- Null check ---
plt.figure(figsize=(10,4))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Data Overview")
plt.show()

# %%
# --- Correlation Heatmap ---
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap="viridis")
plt.title("Feature Correlation")
plt.show()

# %%
# Save clean dataset
# Note: Saving to data/processed/cleaned_dataset.csv as requested
output_path = os.path.join(project_root, "data", "processed", "cleaned_dataset.csv")
# save_processed_dataset(df, output_path)

print("Dataset saved!")
# Out:
# Dataset saved!
